# %%
import os
import re
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
import pandas as pd
from datetime import datetime

# %% [markdown]
# ### Retrieve recovered hdr files from the Raw Data Archive

# %%
# User-defined variables
recovery_string = "R00002"
ifcb_number     = "sn206"     # as the ifcb number appears in the raw data archive directory structure for ifcb data (format: snXXX)
download_folder = f"Recovered_PLIMS_Data/{recovery_string}_HDRs/"
os.makedirs(download_folder, exist_ok=True)

# Parent (no wildcard in URL)
parent_url = f"https://rawdata.oceanobservatories.org/files/CP10CNSM/{recovery_string}/instruments/dcl27/"

# %%
YEAR_RE = re.compile(r"^\d{4}$", re.ASCII)
MONTH_RE = re.compile(r"^\d{6}$", re.ASCII)  # e.g. 202504

filenames = []

def _fetch_soup(url, session, timeout=30):
    r = session.get(url, timeout=timeout)
    r.raise_for_status()
    return BeautifulSoup(r.text, "html.parser")

def _list_entries(url, session):
    """
    Return (dirs, files) as absolute URLs found on an autoindex page.
    """
    soup = _fetch_soup(url, session)
    dirs, files = [], []
    for a in soup.find_all("a"):
        href = a.get("href")
        if not href or href.startswith("?") or href.startswith("/"):
            continue
        abs_url = urljoin(url, href)
        if href.endswith("/"):
            if "beads" in href.lower():
                continue
            dirs.append(abs_url)
        else:
            files.append(abs_url)
    return dirs, files

def _basename(url):
    path = urlparse(url).path.rstrip("/")
    return path.rsplit("/", 1)[-1]

def _find_plims_dirs(session):
    """
    Find PLIMS* directories under parent_url.
    If ifcb_number is set (e.g., 'sn199'), keep only PLIMS_sn199.
    """
    dirs, _ = _list_entries(parent_url, session)
    plims_dirs = [d for d in dirs if _basename(d).startswith("PLIMS")]
    if ifcb_number:
        target = f"PLIMS_{ifcb_number}"
        plims_dirs = [d for d in plims_dirs if _basename(d) == target]
    return plims_dirs

def _iter_year_dirs(plims_dir, session):
    """
    Yield subdirectories whose basename is a 4-digit year.
    """
    dirs, _ = _list_entries(plims_dir, session)
    for d in dirs:
        name = _basename(d)
        if YEAR_RE.match(name):
            yield d

def _iter_month_dirs(year_dir, session):
    """
    Yield subdirectories whose basename is a 6-digit YYYYMM month folder.
    """
    dirs, _ = _list_entries(year_dir, session)
    for d in dirs:
        name = _basename(d)
        if MONTH_RE.match(name):
            yield d

def _recurse_and_download_hdrs(root_url, session, download_dir):
    """
    DFS: list files here, download .hdr, then recurse into subdirs.
    """
    dirs, files = _list_entries(root_url, session)

    # Download .hdr files at this level
    for f in files:
        if f.endswith(".hdr"):
            fname = _basename(f)
            fpath = os.path.join(download_dir, fname)
            if not os.path.exists(fpath):
                print(f"⬇️  Downloading: {fname}")
                with session.get(f, timeout=60, stream=True) as r:
                    r.raise_for_status()
                    with open(fpath, "wb") as out:
                        for chunk in r.iter_content(chunk_size=1 << 15):
                            if chunk:
                                out.write(chunk)
                filenames.append(fname)
            else:
                print(f"✅ Already exists: {fname}")

    # Recurse into all subdirs under this node
    for d in dirs:
        _recurse_and_download_hdrs(d, session, download_dir)

def run():
    with requests.Session() as s:
        s.headers["User-Agent"] = "ooi-plims-crawler/1.0 (+local)"
        plims_dirs = _find_plims_dirs(s)

        if not plims_dirs:
            print("⚠️  No PLIMS directories found matching your criteria.")
            return

        for plims in plims_dirs:
            print(f"🔎 Scanning PLIMS dir: {plims}")
            for ydir in _iter_year_dirs(plims, s):
                print(f"📁 Entering year dir: {ydir}")
                for mdir in _iter_month_dirs(ydir, s):
                    print(f"🗓️  Entering month dir: {mdir}")
                    _recurse_and_download_hdrs(mdir, s, download_folder)

    print("✅ All .hdr files downloaded.")

if __name__ == "__main__":
    run()
# Out:
# 🔎 Scanning PLIMS dir: https://rawdata.oceanobservatories.org/files/CP10CNSM/R00002/instruments/dcl27/PLIMS_sn206/
# 📁 Entering year dir: https://rawdata.oceanobservatories.org/files/CP10CNSM/R00002/instruments/dcl27/PLIMS_sn206/2025/
# 🗓️  Entering month dir: https://rawdata.oceanobservatories.org/files/CP10CNSM/R00002/instruments/dcl27/PLIMS_sn206/2025/202504/
# ⬇️  Downloading: D20250402T142327_IFCB206.hdr
# ⬇️  Downloading: D20250402T143748_IFCB206.hdr
# ⬇️  Downloading: D20250402T152755_IFCB206.hdr
# ⬇️  Downloading: D20250402T154216_IFCB206.hdr
# ⬇️  Downloading: D20250402T161937_IFCB206.hdr
# ⬇️  Downloading: D20250402T182645_IFCB206.hdr
# ⬇️  Downloading: D20250402T212646_IFCB206.hdr
# ⬇️  Downloading: D20250403T002645_IFCB206.hdr
# ⬇️  Downloading: D20250403T032645_IFCB206.hdr
# ⬇️  Downloading: D20250403T062646_IFCB206.hdr
# ⬇️  Downloading: D20250403T092645_IFCB206.hdr
# ⬇️  Downloading: D20250403T122646_IFCB206.hdr
# ⬇️  Downloading: D20250403T212650_IFCB206.hdr
# ⬇️  Downloading: D20250404T002646_IFCB206.hdr
# ⬇️  Downloading: D20250404T032646_IFCB206.hdr
# ⬇️  Downloading: D20250404T062644_IFCB206.hdr
# ⬇️  Downloading: D20250404T092646_IFCB206.hdr
# ⬇️  Downloading: D20250404T122645_IFCB206.hdr
# ⬇️  Downloading: D20250404T152646_IFCB206.hdr
# ⬇️  Downloading: D20250404T212703_IFCB206.hdr
# ⬇️  Downloading: D20250405T002645_IFCB206.hdr
# ⬇️  Downloading: D20250405T032647_IFCB206.hdr
# ⬇️  Downloading: D20250405T062644_IFCB206.hdr
# ⬇️  Downloading: D20250405T092645_IFCB206.hdr
# ⬇️  Downloading: D20250405T122646_IFCB206.hdr
# ⬇️  Downloading: D20250405T131454_IFCB206.hdr
# ⬇️  Downloading: D20250405T133610_IFCB206.hdr
# ⬇️  Downloading: D20250405T141029_IFCB206.hdr
# ⬇️  Downloading: D20250405T143146_IFCB206.hdr
# ⬇️  Downloading: D20250405T152532_IFCB206.hdr
# %%
# these are the variables that will need to be updated per recovery 
cnsm_surveyed_anchor_position_lat = 35.950967 # taken from Pioneer 22 QLR 
cnsm_surveyed_anchor_position_lon = -75.130817 # taken from Pioneer 22 QLR 
cruise = 'AR98' # no cruise number for moored plims data, this is just used in the file name
ifcb_instrument_num = 'IFCB206' # use format: IFCBXXX
metadata_rows = []

columns_in_metadata_csv = ['filename', 'Latitude', 'Longitude', 'Depth', 'sample_type', 'Cruise', 'Instrument', 'tag1', 'tag2', 'tag3','tag4']

for fname in filenames:
    row = {
        'filename': fname.replace('.hdr', ''),
        'Latitude': cnsm_surveyed_anchor_position_lat,
        'Longitude': cnsm_surveyed_anchor_position_lon,
        'Depth': 7,
        'sample_type': 'moored',
        'Cruise': '',
        'Instrument': ifcb_instrument_num,
        'tag1': 'site_CP10CNSM',
        'tag2': 'targetdepth_7m',
        'tag3': '', # tag 3 is the second site tag in the shipboard IFCB metadta file, which is NA for moored data
        'tag4': '', # tag 4 and any subsequent tags are used for quality control tags and prefaced by "qc_" (e.g. qc_bad_focus)
    }
    metadata_rows.append(row)

plims_metadata_df = pd.DataFrame(metadata_rows)

plims_metadata_df
# Out:
#                     filename   Latitude  Longitude  Depth sample_type Cruise
# 0   D20250402T142327_IFCB206  35.950967 -75.130817      7      moored         \
# 1   D20250402T143748_IFCB206  35.950967 -75.130817      7      moored
# 2   D20250402T152755_IFCB206  35.950967 -75.130817      7      moored
# 3   D20250402T154216_IFCB206  35.950967 -75.130817      7      moored
# 4   D20250402T161937_IFCB206  35.950967 -75.130817      7      moored
# ..                       ...        ...        ...    ...         ...    ...
# 72  D20250411T032713_IFCB206  35.950967 -75.130817      7      moored
# 73  D20250411T062654_IFCB206  35.950967 -75.130817      7      moored
# 74  D20250411T092657_IFCB206  35.950967 -75.130817      7      moored
# 75  D20250411T122654_IFCB206  35.950967 -75.130817      7      moored
# 76  D20250411T152656_IFCB206  35.950967 -75.130817      7      moored
#
#    Instrument           tag1            tag2 tag3 tag4
# 0     IFCB206  site_CP10CNSM  targetdepth_7m
# 1     IFCB206  site_CP10CNSM  targetdepth_7m
# 2     IFCB206  site_CP10CNSM  targetdepth_7m
# 3     IFCB206  site_CP10CNSM  targetdepth_7m
# 4     IFCB206  site_CP10CNSM  targetdepth_7m
# ..        ...            ...             ...  ...  ...
# 72    IFCB206  site_CP10CNSM  targetdepth_7m
# 73    IFCB206  site_CP10CNSM  targetdepth_7m
# 74    IFCB206  site_CP10CNSM  targetdepth_7m
# 75    IFCB206  site_CP10CNSM  targetdepth_7m
# 76    IFCB206  site_CP10CNSM  targetdepth_7m
#
# [77 rows x 11 columns]

# %%
timestamp = datetime.now().strftime("%Y-%m-%d_%H%M%S")
output_filename = f"Metadata_CSVs/{cruise}_moored_ifcb_dashboard_metadata_{timestamp}.csv"
plims_metadata_df.to_csv(output_filename, index=False)
