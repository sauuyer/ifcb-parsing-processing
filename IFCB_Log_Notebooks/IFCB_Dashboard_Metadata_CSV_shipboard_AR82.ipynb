# %%
import pandas as pd
from datetime import datetime

# %%
# Read in and standardize Underway data
processed_underway_ifcb_data = pd.read_excel('IFCB_Logs/Pioneer-20_AR82_IFCB_Log_2025-05-19_Ver_1-00.xlsx', sheet_name=1, header=3)
processed_underway_ifcb_data = processed_underway_ifcb_data.fillna('')
processed_underway_ifcb_data.columns = processed_underway_ifcb_data.columns.str.strip()


# Read in and standardize Discrete data
processed_discrete_ifcb_data = pd.read_excel('IFCB_Logs/Pioneer-20_AR82_IFCB_Log_2025-05-19_Ver_1-00.xlsx', sheet_name=2, header=3)
processed_discrete_ifcb_data = processed_discrete_ifcb_data.fillna('')
processed_discrete_ifcb_data.columns = processed_discrete_ifcb_data.columns.str.strip()

# Read in the bottle files (the datetimes from here are needed for discrete samples)

cruise = 'AR82' # format example: AR82
ifcb_instrument_num = 'IFCB206' # format: IFCBXXX

#this is the only block that contains variables that need to be updated
processed_discrete_ifcb_data.columns.tolist()


processed_discrete_ifcb_data['Cast'] = pd.to_numeric(processed_discrete_ifcb_data['Cast'], errors='coerce')
processed_discrete_ifcb_data['Niskin'] = pd.to_numeric(processed_discrete_ifcb_data['Niskin'], errors='coerce')
processed_discrete_ifcb_data = processed_discrete_ifcb_data.dropna(subset=['Cast', 'Niskin'])
processed_discrete_ifcb_data['Cast'] = processed_discrete_ifcb_data['Cast'].astype(int)
processed_discrete_ifcb_data['Niskin'] = processed_discrete_ifcb_data['Niskin'].astype(int)


processed_discrete_ifcb_data
# Out:
#                     Filename                     HDR Comment
# 1   D20240403T154310_IFCB206                ar82a_c6n3_cn_7m  \
# 2   D20240403T160705_IFCB206                ar82a_c6n3_cn_7m
# 3   D20240403T163100_IFCB206                ar82a_c6n3_cn_7m
# 4   D20240403T165903_IFCB206                ar82a_c6n3_cn_7m
# 5   D20240403T172257_IFCB206                ar82a_c6n3_cn_7m
# ..                       ...                             ...
# 62  D20240416T225730_IFCB206  ar82b_cast4n6_b3_so_chlmax_23m
# 63  D20240416T232124_IFCB206  ar82b_cast4n6_b3_so_chlmax_23m
# 64  D20240417T150235_IFCB206        ar82b_c5n9_b1_no_surface
# 65  D20240417T152629_IFCB206        ar82b_c5n9_b1_no_surface
# 66  D20240417T155024_IFCB206        ar82b_c5n9_b1_no_surface
#
#               Sample Type Cruise Leg      Site  Cast  Niskin IFCB Bottle
# 1   discrete_water_sample          a  CP10CNSM     6       3         2.0  \
# 2   discrete_water_sample          a  CP10CNSM     6       3         2.0
# 3   discrete_water_sample          a  CP10CNSM     6       3         2.0
# 4   discrete_water_sample          a  CP10CNSM     6       3         2.0
# 5   discrete_water_sample          a  CP10CNSM     6       3         2.0
# ..                    ...        ...       ...   ...     ...         ...
# 62  discrete_water_sample          b  CP11SOSM     4       6         3.0
# 63  discrete_water_sample          b  CP11SOSM     4       6         3.0
# 64  discrete_water_sample          b  CP11NOSM     5       9         1.0
# 65  discrete_water_sample          b  CP11NOSM     5       9         1.0
# 66  discrete_water_sample          b  CP11NOSM     5       9         1.0
#
#    Target Cast Depth Trip Depth  # Triggers  # ROIs     Run time
# 1                  7        9.0        5260    4118  1201.440139  \
# 2                  7        9.0        4073    3743  1201.380833
# 3                  7        9.0        3580    3424  1201.203056
# 4                  7        9.0        3619    3393  1201.174444
# 5                  7        9.0        3397    3200  1200.995417
# ..               ...        ...         ...     ...          ...
# 62           chl max       23.0        2953    2849  1200.838333
# 63           chl max       23.0        2691    2534  1201.064583
# 64           surface        3.0        3678    3363  1200.890139
# 65           surface        3.0        3131    2983  1200.981528
# 66           surface        3.0        3173    3029  1200.914444
#
#     Inhibit time  Sample time  Volume Analyzed      ROIs/ml
# 1     438.834583   762.605556         3.177523  1295.977970  \
# 2     340.119097   861.261736         3.588591  1043.027877
# 3     297.519965   903.683090         3.765346   909.345332
# 4     301.459549   899.714896         3.748812   905.086716
# 5     282.337274   918.658142         3.827742   836.001952
# ..           ...          ...              ...          ...
# 62    246.417691   954.420642         3.976753   716.413675
# 63    224.580781   976.483802         4.068683   622.806030
# 64    308.291354   892.598785         3.719162   904.236051
# 65    261.290139   939.691389         3.915381   761.867150
# 66    264.883611   936.030833         3.900128   776.641083
#
#    Cast Start Latitude Cast Start Longitude Notes
# 1            35.949883           -75.125817
# 2            35.949883           -75.125817
# 3            35.949883           -75.125817
# 4            35.949883           -75.125817
# 5            35.949883           -75.125817
# ..                 ...                  ...   ...
# 62           35.725033            -74.85305
# 63           35.725033            -74.85305
# 64           36.175117           -74.826233
# 65           36.175117           -74.826233
# 66           36.175117           -74.826233
#
# [66 rows x 20 columns]

# %%
df
# Out:
#     Cruise Leg Cast Niskin Cruise          Start Time [UTC]
# 0            a    1      1  AR82A  2024-04-01T20:51:02.000Z  \
# 1            a    1      2  AR82A  2024-04-01T20:51:02.000Z
# 2            a    1      3  AR82A  2024-04-01T20:51:02.000Z
# 3            a    2      1  AR82A  2024-04-01T23:11:44.000Z
# 4            a    2      2  AR82A  2024-04-01T23:11:44.000Z
# ..         ...  ...    ...    ...                       ...
# 132          b   16      1  AR82B  2024-04-19T13:57:13.000Z
# 133          b   17      1  AR82B  2024-04-19T14:52:54.000Z
# 134          b   18      1  AR82B  2024-04-19T15:47:31.000Z
# 135          b   19      1  AR82B  2024-04-19T16:45:34.000Z
# 136          b   20      1  AR82B  2024-04-19T17:44:32.000Z
#
#      Start Longitude [degrees]  Start Latitude [degrees]       Filename
# 0                   -70.883667                 40.696667  ar82a_001.hex  \
# 1                   -70.883667                 40.696667  ar82a_001.hex
# 2                   -70.883667                 40.696667  ar82a_001.hex
# 3                   -70.885000                 40.365000  ar82a_002.hex
# 4                   -70.885000                 40.365000  ar82a_002.hex
# ..                         ...                       ...            ...
# 132                 -74.874667                 35.876333  ar82b_016.hex
# 133                 -74.845500                 35.949667  ar82b_017.hex
# 134                 -74.836000                 36.024167  ar82b_018.hex
# 135                 -74.837167                 36.099167  ar82b_019.hex
# 136                 -74.826667                 36.174500  ar82b_020.hex
#
#                      datetime  Pressure, Digiquartz [db]  ...
# 0    2024-04-01T20:55:33.000Z                     61.834  ...  \
# 1    2024-04-01T20:59:29.000Z                     30.833  ...
# 2    2024-04-01T21:02:43.000Z                      4.483  ...
# 3    2024-04-01T23:17:25.000Z                     87.547  ...
# 4    2024-04-01T23:21:33.000Z                     30.361  ...
# ..                        ...                        ...  ...
# 132  2024-04-19T14:03:01.000Z                     92.996  ...
# 133  2024-04-19T14:57:53.000Z                     96.901  ...
# 134  2024-04-19T15:53:21.000Z                     97.273  ...
# 135  2024-04-19T16:52:10.000Z                     97.535  ...
# 136  2024-04-19T17:50:59.000Z                     97.306  ...
#
#      Conductivity [S/m]  Conductivity, 2 [S/m]  Salinity, Practical [PSU]
# 0              3.140967               3.140632                    31.9478  \
# 1              3.110245               3.110559                    31.7192
# 2              3.132077               3.132495                    31.7210
# 3              3.186009               3.186277                    32.2736
# 4              3.183689               3.184011                    32.1693
# ..                  ...                    ...                        ...
# 132            4.071344               4.072311                    34.2360
# 133            4.229610               4.230751                    34.7815
# 134            3.888943               3.890178                    34.2146
# 135            3.883716               3.884120                    34.1732
# 136            4.189189               4.189395                    34.8829
#
#      Salinity, Practical, 2 [PSU]  Oxygen raw, SBE 43 [V]
# 0                         31.9476                  2.6200  \
# 1                         31.7232                  2.6536
# 2                         31.7253                  2.7010
# 3                         32.2771                  2.6273
# 4                         32.1725                  2.6747
# ..                            ...                     ...
# 132                       34.2420                  2.4953
# 133                       34.7867                  2.4110
# 134                       34.2190                  2.3467
# 135                       34.1763                  2.3720
# 136                       34.8852                  2.3408
#
#      Oxygen, SBE 43 [ml/l]  Oxygen Saturation, Garcia & Gordon [ml/l]
# 0                   6.9041                                    7.10319  \
# 1                   7.0169                                    7.13229
# 2                   7.0960                                    7.08645
# 3                   6.9049                                    7.05838
# 4                   6.9904                                    7.04481
# ..                     ...                                        ...
# 132                 5.3343                                    5.89071
# 133                 4.9877                                    5.74982
# 134                 5.1526                                    6.12885
# 135                 5.2280                                    6.13186
# 136                 4.8582                                    5.80750
#
#      Beam Attenuation, WET Labs C-Star [1/m]
# 0                                     0.7375  \
# 1                                     0.7247
# 2                                     0.7330
# 3                                     0.5762
# 4                                     0.5262
# ..                                       ...
# 132                                   0.1798
# 133                                   0.1128
# 134                                   0.1205
# 135                                   0.1700
# 136                                   0.0312
#
#      Beam Transmission, WET Labs C-Star [%]
# 0                                   83.1616  \
# 1                                   83.4280
# 2                                   83.2569
# 3                                   86.5844
# 4                                   87.6747
# ..                                      ...
# 132                                 95.6052
# 133                                 97.2189
# 134                                 97.0323
# 135                                 95.8382
# 136                                 99.2234
#
#      Fluorescence, WET Labs ECO-AFL/FL [mg/m^3]
# 0                                  0.4281 (avg)
# 1                                  0.6732 (avg)
# 2                                  1.1356 (avg)
# 3                                  0.6131 (avg)
# 4                                  0.9087 (avg)
# ..                                          ...
# 132                                0.1303 (avg)
# 133                                0.0487 (avg)
# 134                                0.0744 (avg)
# 135                                0.0851 (avg)
# 136                                0.0483 (avg)
#
# [137 rows x 25 columns]

# %%
df = pd.read_excel('Bottle_file_copies/merged_bottle_data_csvs/AR82_merged_bottle_data.xlsx')
df = df.rename(columns={'Bottle Position': 'Niskin'})

# Ensure consistent types in both DataFrames
# For bottle file
df['Cruise Leg'] = df['Cruise Leg'].astype(str)
df['Cast'] = df['Cast'].astype(int).astype(str)
df['Niskin'] = df['Niskin'].astype(int).astype(str)

# For IFCB log data
processed_discrete_ifcb_data['Cruise Leg'] = processed_discrete_ifcb_data['Cruise Leg'].astype(str)
processed_discrete_ifcb_data['Cast'] = processed_discrete_ifcb_data['Cast'].astype(int).astype(str)
processed_discrete_ifcb_data['Niskin'] = processed_discrete_ifcb_data['Niskin'].astype(int).astype(str)


# Now merge
merged = processed_discrete_ifcb_data.merge(
    df[['Cruise Leg', 'Cast', 'Niskin', 'datetime']],
    on=['Cruise Leg', 'Cast', 'Niskin'],
    how='left'
)
merged = merged.rename(columns={'datetime': 'bottle_datetime'})
merged.head()

processed_discrete_ifcb_data = merged
processed_discrete_ifcb_data.head()
# Out:
#                    Filename       HDR Comment            Sample Type
# 0  D20240403T154310_IFCB206  ar82a_c6n3_cn_7m  discrete_water_sample  \
# 1  D20240403T160705_IFCB206  ar82a_c6n3_cn_7m  discrete_water_sample
# 2  D20240403T163100_IFCB206  ar82a_c6n3_cn_7m  discrete_water_sample
# 3  D20240403T165903_IFCB206  ar82a_c6n3_cn_7m  discrete_water_sample
# 4  D20240403T172257_IFCB206  ar82a_c6n3_cn_7m  discrete_water_sample
#
#   Cruise Leg      Site Cast Niskin IFCB Bottle Target Cast Depth Trip Depth
# 0          a  CP10CNSM    6      3         2.0                 7        9.0  \
# 1          a  CP10CNSM    6      3         2.0                 7        9.0
# 2          a  CP10CNSM    6      3         2.0                 7        9.0
# 3          a  CP10CNSM    6      3         2.0                 7        9.0
# 4          a  CP10CNSM    6      3         2.0                 7        9.0
#
#    ...  # ROIs     Run time  Inhibit time  Sample time  Volume Analyzed
# 0  ...    4118  1201.440139    438.834583   762.605556         3.177523  \
# 1  ...    3743  1201.380833    340.119097   861.261736         3.588591
# 2  ...    3424  1201.203056    297.519965   903.683090         3.765346
# 3  ...    3393  1201.174444    301.459549   899.714896         3.748812
# 4  ...    3200  1200.995417    282.337274   918.658142         3.827742
#
#        ROIs/ml  Cast Start Latitude Cast Start Longitude Notes
# 0  1295.977970            35.949883           -75.125817        \
# 1  1043.027877            35.949883           -75.125817
# 2   909.345332            35.949883           -75.125817
# 3   905.086716            35.949883           -75.125817
# 4   836.001952            35.949883           -75.125817
#
#             bottle_datetime
# 0  2024-04-03T14:29:26.000Z
# 1  2024-04-03T14:29:26.000Z
# 2  2024-04-03T14:29:26.000Z
# 3  2024-04-03T14:29:26.000Z
# 4  2024-04-03T14:29:26.000Z
#
# [5 rows x 21 columns]

# %%
columns_in_metadata_csv = ['filename', 'Latitude', 'Longitude', 'Depth', 'sample_type', 'Cruise', 'Instrument', 'tag1', 'tag2', 'tag3', 'datetime']

processed_underway_ifcb_data_mapped = {
    'filename': processed_underway_ifcb_data['Filename'], 
    'Latitude': processed_underway_ifcb_data['Ship Latitude'],
    'Longitude': processed_underway_ifcb_data['Ship Longitude'],
    'Depth': 2.13, #for R/V Armstrong Aft Diaphram Pump
    'sample_type': 'underway',
    'Cruise': cruise,
    'Instrument': ifcb_instrument_num,
    'tag1': processed_underway_ifcb_data['Site'].apply(lambda x: 'site_' + str(x) if pd.notna(x) and x != '' else x), 
    'tag2': 'targetdepth_surface',
    'tag3': '',
    'datetime': ''
}

processed_discrete_ifcb_data_mapped = {
    'filename': processed_discrete_ifcb_data['Filename'], 
    'Latitude': processed_discrete_ifcb_data['Cast Start Latitude'],
    'Longitude': processed_discrete_ifcb_data['Cast Start Longitude'],
    'Depth': processed_discrete_ifcb_data['Trip Depth'],
    'sample_type': processed_discrete_ifcb_data['Sample Type'].apply(
        lambda x: 'discrete' if 'discrete' in str(x).lower() and 'test' not in str(x).lower() and 'beads' not in str(x).lower() else x
    ),
    'Cruise': cruise,
    'Instrument':ifcb_instrument_num,
    'tag1': processed_discrete_ifcb_data['Site'].apply(lambda x: 'site_' + str(x) if pd.notna(x) and x != '' else x), 
    'tag2': processed_discrete_ifcb_data['Target Cast Depth'].apply(lambda x: 'site_' + str(x) if pd.notna(x) and x != '' else x), 
    'tag3': processed_discrete_ifcb_data.apply(
        lambda row: 'qc_' + str(row['Sample Type']) if (
            (pd.notna(row['Sample Type']) and 'test' in str(row['Sample Type']).lower()) or 
            (pd.notna(row['HDR Comment']) and 'test' in str(row['HDR Comment']).lower()) or
            (pd.notna(row['Sample Type']) and 'beads' in str(row['Sample Type']).lower()) or 
            (pd.notna(row['HDR Comment']) and 'beads' in str(row['HDR Comment']).lower())
        ) else '', axis=1
    ),
    'datetime': processed_discrete_ifcb_data['bottle_datetime']
}


underway_new = pd.DataFrame(processed_underway_ifcb_data_mapped)
discrete_new = pd.DataFrame(processed_discrete_ifcb_data_mapped)


metadata_df = pd.concat([underway_new, discrete_new], ignore_index=True)


metadata_df
# Out:
#                      filename   Latitude  Longitude Depth sample_type Cruise
# 0    D20240401T151712_IFCB206     41.524    -70.672  2.13    underway   AR82  \
# 1    D20240401T173608_IFCB206     41.524    -70.672  2.13    underway   AR82
# 2    D20240401T180004_IFCB206     41.524    -70.672  2.13    underway   AR82
# 3    D20240401T182359_IFCB206     41.524    -70.672  2.13    underway   AR82
# 4    D20240401T184754_IFCB206     40.291    -70.882  2.13    underway   AR82
# ..                        ...        ...        ...   ...         ...    ...
# 945  D20240416T225730_IFCB206  35.725033  -74.85305  23.0    discrete   AR82
# 946  D20240416T232124_IFCB206  35.725033  -74.85305  23.0    discrete   AR82
# 947  D20240417T150235_IFCB206  36.175117 -74.826233   3.0    discrete   AR82
# 948  D20240417T152629_IFCB206  36.175117 -74.826233   3.0    discrete   AR82
# 949  D20240417T155024_IFCB206  36.175117 -74.826233   3.0    discrete   AR82
#
#     Instrument           tag1                 tag2 tag3
# 0      IFCB206                 targetdepth_surface       \
# 1      IFCB206                 targetdepth_surface
# 2      IFCB206                 targetdepth_surface
# 3      IFCB206                 targetdepth_surface
# 4      IFCB206                 targetdepth_surface
# ..         ...            ...                  ...  ...
# 945    IFCB206  site_CP11SOSM         site_chl max
# 946    IFCB206  site_CP11SOSM         site_chl max
# 947    IFCB206  site_CP11NOSM         site_surface
# 948    IFCB206  site_CP11NOSM         site_surface
# 949    IFCB206  site_CP11NOSM         site_surface
#
#                      datetime
# 0
# 1
# 2
# 3
# 4
# ..                        ...
# 945  2024-04-16T19:58:52.000Z
# 946  2024-04-16T19:58:52.000Z
# 947  2024-04-17T14:15:56.000Z
# 948  2024-04-17T14:15:56.000Z
# 949  2024-04-17T14:15:56.000Z
#
# [950 rows x 11 columns]

# %%
timestamp = datetime.now().strftime("%Y-%m-%d_%H%M%S")
output_filename = f"Metadata_CSVs/AR82_shipboard_ifcb_dashboard_metadata_{timestamp}.csv"
metadata_df.to_csv(output_filename, index=False)
